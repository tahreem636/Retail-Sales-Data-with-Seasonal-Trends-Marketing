# %% [markdown]
# <a href="https://colab.research.google.com/github/tahreem636/Retail-Sales-Data-with-Seasonal-Trends-Marketing/blob/main/retail%20sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/CONTENT/'

# %%
# !kaggle datasets download -d abdullah0a/retail-sales-data-with-seasonal-trends-and-marketing
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/abdullah0a/retail-sales-data-with-seasonal-trends-and-marketing
# License(s): MIT
# ...
#   0% 0.00/610k [00:00<?, ?B/s]
# 100% 610k/610k [00:00<00:00, 83.4MB/s]

# %%
import pandas as pd
df = pd.read_csv('retail-sales-data-with-seasonal-trends-and-marketing.zip')
df
# Out:
#        YEAR  MONTH                              SUPPLIER ITEM CODE  \
# 0      2020      1     REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                             PWSWN INC    100024
# 2      2020      1               RELIABLE CHURCHILL LLLP      1001
# 3      2020      1             LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1                  DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                   ...       ...
# 29995  2020      3  THE COUNTRY VINTNER, LLC DBA WINEBOW    352322
# 29996  2020      3                       OSLO ENTERPRISE    352324
# 29997  2020      3       OPICI FAMILY DISTRIBUTING OF MD    352354
# 29998  2020      3                   CAMPARI AMERICA LLC     35238
# 29999  2020      3  THE COUNTRY VINTNER, LLC DBA WINEBOW    352380
#
#                             ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                        BOOTLEG RED - 750ML      WINE          0.00
# ...
